# %%
from pandas import * 
import numpy as np

# %%
df = read_csv('cost-of-living.csv')

# %%
df.head()
# Out:
#                                                 type  \
# 0                       Meal, Inexpensive Restaurant
# 1  Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
#
#    Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                      7.34              4.58           3.06
# 1                     29.35             15.28          12.22
# 2                      4.40              3.82           3.06
# 3                      2.20              3.06           2.29
# 4                      2.20              3.06           2.75
#
#    Helsinki, Finland  Chisinau, Moldova  Milan, Italy  Cairo, Egypt  \
# 0              12.00               4.67          15.0          3.38
# 1              65.00              20.74          60.0         17.48
# ...

# %%
 df.get_dtype_counts()
# Out:
# c:\users\vkironv\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   """Entry point for launching an IPython kernel.
# float64    160
# object       1
# dtype: int64

# %%
df
# Out:
#                                                  type  \
# 0                        Meal, Inexpensive Restaurant
# 1   Meal for 2 People, Mid-range Restaurant, Three...
# 2      McMeal at McDonalds (or Equivalent Combo Meal)
# 3                   Domestic Beer (0.5 liter draught)
# 4                   Imported Beer (0.33 liter bottle)
# 5                      Coke/Pepsi (0.33 liter bottle)
# 6                          Water (0.33 liter bottle)
# 7                           Milk (regular), (1 liter)
# 8                    Loaf of Fresh White Bread (500g)
# 9                                 Eggs (regular) (12)
# 10                                 Local Cheese (1kg)
# 11                           Water (1.5 liter bottle)
# 12                         Bottle of Wine (Mid-Range)
# 13                   Domestic Beer (0.5 liter bottle)
# 14                  Imported Beer (0.33 liter bottle)
# 15                      Cigarettes 20 Pack (Marlboro)
# ...

# %%
x=df.drop(df.index[[1,2,4,5,6,11,12,13,26,14,15,16,17,19,21,22,23,28,24,29,31,32,18,33,34,35,20,36,37,25,38,39,40,41,46,49,50,51,30,41,42,43,44,53,39,40,41,28,52,54]])

x
# Out:
#                                                  type  \
# 0                        Meal, Inexpensive Restaurant
# 3                   Domestic Beer (0.5 liter draught)
# 7                           Milk (regular), (1 liter)
# 8                    Loaf of Fresh White Bread (500g)
# 9                                 Eggs (regular) (12)
# 10                                 Local Cheese (1kg)
# 27  Internet (60 Mbps or More, Unlimited Data, Cab...
# 45                                   Lettuce (1 head)
# 47                                Rice (white), (1kg)
# 48                                       Tomato (1kg)
#
#     Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                       7.34              4.58           3.06
# 3                       2.20              3.06           2.29
# 7                       0.98              0.71           0.65
# 8                       0.71              0.36           0.38
# ...

# %%
#piecharts

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Alexandria, Egypt']
figureObject, axesObject = plt.subplots()
axesObject.pie(g,startangle=90)
axesObject.legend(gs,loc='center left', bbox_to_anchor=(1.0, 0.5))
axesObject.axis('equal')
plt.show()
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Ho Chi Minh City, Vietnam']
figureObject, axesObject = plt.subplots()
axesObject.pie(g,startangle=90)
axesObject.legend(gs,loc='center left', bbox_to_anchor=(1.0, 0.5))
axesObject.axis('equal')
plt.show()
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Saint Petersburg, Russia']
figureObject, axesObject = plt.subplots()
axesObject.pie(g,startangle=90)
axesObject.legend(gs,loc='center left', bbox_to_anchor=(1.0, 0.5))
axesObject.axis('equal')
plt.show()
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Milan, Italy']
figureObject, axesObject = plt.subplots()
axesObject.pie(g,startangle=90)
axesObject.legend(gs,loc='center left', bbox_to_anchor=(1.0, 0.5))
axesObject.axis('equal')
plt.show()
plt.tight_layout()

# %%
#piegraphs

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Alexandria, Egypt']
plt.bar(gs, g, align='center', alpha=0.99)
plt.xticks(rotation=90)
plt.ylabel('cost')
plt.xlabel('criterias')

plt.show()

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Saint Petersburg, Russia']
plt.bar(gs, g, align='center', alpha=0.99)
plt.xticks(rotation=90)
plt.ylabel('cost')
plt.xlabel('criterias')

plt.show()

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Milan, Italy']
plt.bar(gs, g, align='center', alpha=0.99)
plt.xticks(rotation=90)
plt.ylabel('cost')
plt.xlabel('criterias')

plt.show()

# %%
import matplotlib.pyplot as plt
gs=x['type']
g=x['Ho Chi Minh City, Vietnam']
plt.bar(gs, g, align='center', alpha=0.99)
plt.xticks(rotation=90)
plt.ylabel('cost')
plt.xlabel('criterias')

plt.show()

# %%
#linegraphs

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 500
x1 = x['type']
y1 = x['Ho Chi Minh City, Vietnam']
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x1, y1, s=area,  alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel('criteria')
plt.ylabel('cost')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 500
x1 = x['type']
y1 = x['Milan, Italy']
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x1, y1, s=area, alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel('criteria')
plt.ylabel('cost')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 500
x1 = x['type']
y1 = x['Saint Petersburg, Russia']
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x1, y1, s=area, alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel('criteria')
plt.ylabel('cost')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 500
x1 = x['type']
y1 = x['Alexandria, Egypt']
colors = (0,0,0)
area = np.pi*3

# Plot
plt.scatter(x1, y1, s=area, alpha=0.5)
plt.xticks(rotation=90)
plt.xlabel('criteria')
plt.ylabel('cost')
plt.show()
